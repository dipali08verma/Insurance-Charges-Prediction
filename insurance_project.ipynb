# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd
data={
    "age":[19,25,32,45,28],
    "sex":["f","m","m","f","m"],
    "bmi":[27,9,22,5,33],
    "charges":[16324,34555,4543,5756,32321]
}
df =pd.DataFrame(data)
df
# Out:
#    age sex  bmi  charges
# 0   19   f   27    16324
# 1   25   m    9    34555
# 2   32   m   22     4543
# 3   45   f    5     5756
# 4   28   m   33    32321

# %%
df.head()
# Out:
#    age sex  bmi  charges
# 0   19   f   27    16324
# 1   25   m    9    34555
# 2   32   m   22     4543
# 3   45   f    5     5756
# 4   28   m   33    32321

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      5 non-null      int64
#  1   sex      5 non-null      str
#  2   bmi      5 non-null      int64
#  3   charges  5 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#              age        bmi       charges
# count   5.000000   5.000000      5.000000
# mean   29.800000  19.200000  18699.800000
# std     9.731393  11.882761  14234.867639
# min    19.000000   5.000000   4543.000000
# 25%    25.000000   9.000000   5756.000000
# 50%    28.000000  22.000000  16324.000000
# 75%    32.000000  27.000000  32321.000000
# max    45.000000  33.000000  34555.000000

# %%
df.isnull()
# Out:
#      age    sex    bmi  charges
# 0  False  False  False    False
# 1  False  False  False    False
# 2  False  False  False    False
# 3  False  False  False    False
# 4  False  False  False    False

# %%
df.shape
# Out:
# (5, 4)

# %%
df.isnull().sum()
# Out:
# age        0
# sex        0
# bmi        0
# charges    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'charges'], dtype='str')

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
df
# Out:
#      age     sex    bmi  children smoker     region   charges
# 0     56  female  38.99         2     no  northeast  13728.85
# 1     46    male  38.13         4    yes  northeast  27106.08
# 2     32  female  26.14         0    yes  northeast  23420.40
# 3     60    male  18.34         3    yes  northeast  25290.53
# 4     25    male  38.42         0    yes  northeast  24459.64
# ..   ...     ...    ...       ...    ...        ...       ...
# 195   49  female  19.60         3     no  northeast  12611.06
# 196   49    male  36.08         0     no  southwest  11997.12
# 197   41  female  33.54         2     no  southeast  11364.11
# 198   58  female  19.79         2    yes  southwest  28143.21
# 199   29  female  19.87         2     no  southeast   9823.54
#
# [200 rows x 7 columns]

# %%
df.shape
# Out:
# (200, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
df.describe()
# Out:
#               age         bmi    children       charges
# count  200.000000  200.000000  200.000000    200.000000
# mean    41.570000   29.119350    2.030000  14007.546650
# std     13.715527    6.561917    1.462805   6534.726278
# min     18.000000   18.240000    0.000000   5144.490000
# 25%     30.000000   24.110000    1.000000   9761.062500
# 50%     42.000000   29.590000    2.000000  11361.940000
# 75%     54.000000   34.690000    3.000000  14441.562500
# max     64.000000   39.790000    4.000000  28561.790000

# %%
df.count
# Out:
# <bound method DataFrame.count of      age     sex    bmi  children smoker     region   charges
# 0     56  female  38.99         2     no  northeast  13728.85
# 1     46    male  38.13         4    yes  northeast  27106.08
# 2     32  female  26.14         0    yes  northeast  23420.40
# 3     60    male  18.34         3    yes  northeast  25290.53
# 4     25    male  38.42         0    yes  northeast  24459.64
# ..   ...     ...    ...       ...    ...        ...       ...
# 195   49  female  19.60         3     no  northeast  12611.06
# 196   49    male  36.08         0     no  southwest  11997.12
# 197   41  female  33.54         2     no  southeast  11364.11
# 198   58  female  19.79         2    yes  southwest  28143.21
# 199   29  female  19.87         2     no  southeast   9823.54
#
# [200 rows x 7 columns]>

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numeric_cols = ["age","bmi","children","charges"]
for col in numeric_cols:
    sns.histplot(df[col],kde =True)
    plt.title(col)
    plt.show()

# %%
sns.countplot(x=df["children"])
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x=df["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=df["smoker"])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
 for col in numeric_cols:
     plt.figure(figsize =(6,4))
     sns.boxplot(x=df[col])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x="smoker",y="charges",data=df)
plt.show()

# %%
sns.boxplot(x="sex",y="charges",data=df)
plt.show()

# %%
sns.boxplot(x="region",y="charges",data=df)
plt.show()

# %%
 #data cleaning
 df.drop_duplicates(inplace =True)

# %%
df_cleaned=df.copy()
df_cleaned.head()
df_cleaned.shape
# Out:
# (200, 7)

# %%
df_cleaned.drop_duplicates(inplace=True)
df_cleaned.shape
# Out:
# (200, 7)

# %%
df_cleaned.isnull().sum()
# Out:
# age        0
# sex        0
# bmi        0
# charges    0
# dtype: int64

# %%
df_cleaned.dtypes
# Out:
# age        int64
# sex          str
# bmi        int64
# charges    int64
# dtype: object

# %%
df.head()
df_cleaned['sex']=df["sex"]
df_cleaned['sex'].unique()
# Out:
# <StringArray>
# ['f', 'm']
# Length: 2, dtype: str

# %%
import pandas as pd
df=pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex    bmi  children smoker     region   charges
# 0   56  female  38.99         2     no  northeast  13728.85
# 1   46    male  38.13         4    yes  northeast  27106.08
# 2   32  female  26.14         0    yes  northeast  23420.40
# 3   60    male  18.34         3    yes  northeast  25290.53
# 4   25    male  38.42         0    yes  northeast  24459.64

# %%
df["sex"].unique
# Out:
# <bound method Series.unique of 0      female
# 1        male
# 2      female
# 3        male
# 4        male
#         ...
# 195    female
# 196      male
# 197    female
# 198    female
# 199    female
# Name: sex, Length: 200, dtype: str>

# %%
df_cleaned = df.copy()
df_cleaned.head()
df_cleaned.shape
# Out:
# (200, 7)

# %%
#convert str into numeric 0,1
df_cleaned['sex'] = df_cleaned['sex'].map({"male": 0, "female": 1})
df_cleaned.head()
# Out:
#    age  sex    bmi  children smoker     region   charges
# 0   56    1  38.99         2     no  northeast  13728.85
# 1   46    0  38.13         4    yes  northeast  27106.08
# 2   32    1  26.14         0    yes  northeast  23420.40
# 3   60    0  18.34         3    yes  northeast  25290.53
# 4   25    0  38.42         0    yes  northeast  24459.64

# %%
df_cleaned['smoker'].value_counts()
df_cleaned['smoker'].unique()
# Out:
# <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str

# %%
#convert str into numeric 0,1
df_cleaned['smoker'] = df_cleaned['smoker'].map({"yes": 0, "no": 1})
df_cleaned.head()
# Out:
#    age     sex    bmi  children  smoker     region   charges
# 0   56  female  38.99         2       1  northeast  13728.85
# 1   46    male  38.13         4       0  northeast  27106.08
# 2   32  female  26.14         0       0  northeast  23420.40
# 3   60    male  18.34         3       0  northeast  25290.53
# 4   25    male  38.42         0       0  northeast  24459.64

# %%
df_cleaned=df.copy()

# %%
df_cleaned['smoker'].unique
# Out:
# <bound method Series.unique of 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    0
# 199    1
# Name: smoker, Length: 200, dtype: int64>

# %%
#convert str into numeric 0,1
df_cleaned['smoker'] = df_cleaned['smoker'].map({"yes": 0, "no": 1})
df_cleaned.head()
# Out:
#    age     sex    bmi  children  smoker     region   charges
# 0   56  female  38.99         2     NaN  northeast  13728.85
# 1   46    male  38.13         4     NaN  northeast  27106.08
# 2   32  female  26.14         0     NaN  northeast  23420.40
# 3   60    male  18.34         3     NaN  northeast  25290.53
# 4   25    male  38.42         0     NaN  northeast  24459.64

# %%
#convert str into numeric 0,1
df_cleaned['sex'] = df_cleaned['sex'].map({"male": 0, "female": 1})
df_cleaned.head()
# Out:
#    age  sex    bmi  children  smoker     region   charges
# 0   56    1  38.99         2     NaN  northeast  13728.85
# 1   46    0  38.13         4     NaN  northeast  27106.08
# 2   32    1  26.14         0     NaN  northeast  23420.40
# 3   60    0  18.34         3     NaN  northeast  25290.53
# 4   25    0  38.42         0     NaN  northeast  24459.64

# %%
df_cleaned["region"].unique
# Out:
# <bound method Series.unique of 0      northeast
# 1      northeast
# 2      northeast
# 3      northeast
# 4      northeast
#          ...
# 195    northeast
# 196    southwest
# 197    southeast
# 198    southwest
# 199    southeast
# Name: region, Length: 200, dtype: str>

# %%
#convert str into numeric 0,1
df_cleaned=pd.get_dummies(df_cleaned,columns=['region'],drop_first=True)

# %%
df_cleaned.head()
# Out:
#    age     sex    bmi  children smoker   charges  region_northwest  \
# 0   56  female  38.99         2     no  13728.85             False
# 1   46    male  38.13         4    yes  27106.08             False
# 2   32  female  26.14         0    yes  23420.40             False
# 3   60    male  18.34         3    yes  25290.53             False
# 4   25    male  38.42         0    yes  24459.64             False
#
#    region_southeast  region_southwest
# 0             False             False
# 1             False             False
# 2             False             False
# 3             False             False
# 4             False             False

# %%
import pandas as pd
df= pd.read_csv("insurance.csv")
df_cleaned=df.copy()

# %%
#FEATURE ENGINEERIING AND EXTRACTION
df_cleaned['bmi_category']=pd.cut(
    df_cleaned['bmi'],
    bins=[0,18.5,24.9,29 ,100],
    labels=["underweight","normal","overweignt","obese"]
)
df_cleaned
# Out:
#      age  sex    bmi  children  smoker   charges  region_northwest  \
# 0     56    1  38.99         2     NaN  13728.85             False
# 1     46    0  38.13         4     NaN  27106.08             False
# 2     32    1  26.14         0     NaN  23420.40             False
# 3     60    0  18.34         3     NaN  25290.53             False
# 4     25    0  38.42         0     NaN  24459.64             False
# ..   ...  ...    ...       ...     ...       ...               ...
# 195   49    1  19.60         3     NaN  12611.06             False
# 196   49    0  36.08         0     NaN  11997.12             False
# 197   41    1  33.54         2     NaN  11364.11             False
# 198   58    1  19.79         2     NaN  28143.21             False
# 199   29    1  19.87         2     NaN   9823.54             False
#
#      region_southeast  region_southwest bmi_category
# 0               False             False        obese
# 1               False             False        obese
# ...

# %%
df_cleaned=pd.get_dummies(df_cleaned,columns=['bmi_category'],drop_first=True)
df_cleaned
# Out:
#      age  sex    bmi  children  smoker   charges  region_northwest  \
# 0     56    1  38.99         2     NaN  13728.85             False
# 1     46    0  38.13         4     NaN  27106.08             False
# 2     32    1  26.14         0     NaN  23420.40             False
# 3     60    0  18.34         3     NaN  25290.53             False
# 4     25    0  38.42         0     NaN  24459.64             False
# ..   ...  ...    ...       ...     ...       ...               ...
# 195   49    1  19.60         3     NaN  12611.06             False
# 196   49    0  36.08         0     NaN  11997.12             False
# 197   41    1  33.54         2     NaN  11364.11             False
# 198   58    1  19.79         2     NaN  28143.21             False
# 199   29    1  19.87         2     NaN   9823.54             False
#
#      region_southeast  region_southwest  bmi_category_normal  \
# 0               False             False                False
# ...

# %%
import pandas as pd

df = pd.read_csv("insurance.csv")
df_cleaned = df.copy()

# %%
#FEATURE ENGINEERIING AND EXTRACTION
df_cleaned['bmi_category'] = pd.cut(
    df_cleaned['bmi'],
    bins=[0, 18.5, 24.9, 29, 100],
    labels=["underweight", "normal", "overweignt", "obese"]
)
df_cleaned
df_cleaned = pd.get_dummies(df_cleaned, columns=['bmi_category'], drop_first=True)

df_cleaned
# Out:
#      age     sex    bmi  children smoker     region   charges  \
# 0     56  female  38.99         2     no  northeast  13728.85
# 1     46    male  38.13         4    yes  northeast  27106.08
# 2     32  female  26.14         0    yes  northeast  23420.40
# 3     60    male  18.34         3    yes  northeast  25290.53
# 4     25    male  38.42         0    yes  northeast  24459.64
# ..   ...     ...    ...       ...    ...        ...       ...
# 195   49  female  19.60         3     no  northeast  12611.06
# 196   49    male  36.08         0     no  southwest  11997.12
# 197   41  female  33.54         2     no  southeast  11364.11
# 198   58  female  19.79         2    yes  southwest  28143.21
# 199   29  female  19.87         2     no  southeast   9823.54
#
#      bmi_category_normal  bmi_category_overweignt  bmi_category_obese
# 0                  False                    False                True
# 1                  False                    False                True
# ...

# %%
df_cleaned.head()
# Out:
#    age  sex    bmi  children  smoker   charges  region_northwest  \
# 0   56    1  38.99         2     NaN  13728.85             False
# 1   46    0  38.13         4     NaN  27106.08             False
# 2   32    1  26.14         0     NaN  23420.40             False
# 3   60    0  18.34         3     NaN  25290.53             False
# 4   25    0  38.42         0     NaN  24459.64             False
#
#    region_southeast  region_southwest  bmi_category_normal  \
# 0             False             False                False
# 1             False             False                False
# 2             False             False                False
# 3             False             False                False
# 4             False             False                False
#
#    bmi_category_overweignt  bmi_category_obese
# 0                    False                True
# 1                    False                True
# 2                     True               False
# ...

# %%
#convert str into numeric 0,1
df_cleaned['smoker'] = df_cleaned['smoker'].map({"yes": 0, "no": 1})
df_cleaned.head()
# Out:
#    age  sex    bmi  children  smoker   charges  region_northwest  \
# 0   56    1  38.99         2     NaN  13728.85             False
# 1   46    0  38.13         4     NaN  27106.08             False
# 2   32    1  26.14         0     NaN  23420.40             False
# 3   60    0  18.34         3     NaN  25290.53             False
# 4   25    0  38.42         0     NaN  24459.64             False
#
#    region_southeast  region_southwest  bmi_category_normal  \
# 0             False             False                False
# 1             False             False                False
# 2             False             False                False
# 3             False             False                False
# 4             False             False                False
#
#    bmi_category_overweignt  bmi_category_obese
# 0                    False                True
# 1                    False                True
# 2                     True               False
# ...

# %%
#convert str into numeric 0,1
df_cleaned['sex'] = df_cleaned['sex'].map({"male": 0, "female": 1})
df_cleaned.head()
# Out:
#    age  sex    bmi  children  smoker   charges  region_northwest  \
# 0   56  NaN  38.99         2     NaN  13728.85             False
# 1   46  NaN  38.13         4     NaN  27106.08             False
# 2   32  NaN  26.14         0     NaN  23420.40             False
# 3   60  NaN  18.34         3     NaN  25290.53             False
# 4   25  NaN  38.42         0     NaN  24459.64             False
#
#    region_southeast  region_southwest  bmi_category_normal  \
# 0             False             False                False
# 1             False             False                False
# 2             False             False                False
# 3             False             False                False
# 4             False             False                False
#
#    bmi_category_overweignt  bmi_category_obese
# 0                    False                True
# 1                    False                True
# 2                     True               False
# ...

# %%
df_cleaned.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges',
#        'region_northwest', 'region_southeast', 'region_southwest',
#        'bmi_category_normal', 'bmi_category_overweignt', 'bmi_category_obese'],
#       dtype='str')

# %%
from sklearn.preprocessing import StandardScaler
cols=['age','bmi','children']
scaler=StandardScaler()
df_cleaned[cols]=scaler.fit_transform(df_cleaned[cols])
df_cleaned.head()
# Out:
#         age  sex       bmi  children  smoker   charges  region_northwest  \
# 0  1.054732  NaN  1.508007 -0.020560     NaN  13728.85             False
# 1  0.323802  NaN  1.376619  1.350107     NaN  27106.08             False
# 2 -0.699500  NaN -0.455176 -1.391227     NaN  23420.40             False
# 3  1.347105  NaN -1.646836  0.664774     NaN  25290.53             False
# 4 -1.211152  NaN  1.420925 -1.391227     NaN  24459.64             False
#
#    region_southeast  region_southwest  bmi_category_normal  \
# 0             False             False                False
# 1             False             False                False
# 2             False             False                False
# 3             False             False                False
# 4             False             False                False
#
#    bmi_category_overweignt  bmi_category_obese
# 0                    False                True
# 1                    False                True
# ...

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# %%
alpha = 0.05

df_cleaned['charges_bin'] = pd.qcut(
    df_cleaned['charges'],
    q=4,
    labels=False
)

# %%
df_cleaned[['charges','charges_bin']].head(10)
# Out:
#     charges  charges_bin
# 0  13728.85            2
# 1  27106.08            3
# 2  23420.40            3
# 3  25290.53            3
# 4  24459.64            3
# 5   8476.25            0
# 6  28077.52            3
# 7  27529.51            3
# 8  25185.08            3
# 9   6705.71            0

# %%
df_cleaned['charges_bin'].value_counts()
# Out:
# charges_bin
# 2    50
# 3    50
# 0    50
# 1    50
# Name: count, dtype: int64

# %%
final_df=df_cleaned
final_df
# Out:
#           age  sex       bmi  children  smoker   charges  region_northwest  \
# 0    1.054732  NaN  1.508007 -0.020560     NaN  13728.85             False
# 1    0.323802  NaN  1.376619  1.350107     NaN  27106.08             False
# 2   -0.699500  NaN -0.455176 -1.391227     NaN  23420.40             False
# 3    1.347105  NaN -1.646836  0.664774     NaN  25290.53             False
# 4   -1.211152  NaN  1.420925 -1.391227     NaN  24459.64             False
# ..        ...  ...       ...       ...     ...       ...               ...
# 195  0.543081  NaN -1.454337  0.664774     NaN  12611.06             False
# 196  0.543081  NaN  1.063427 -1.391227     NaN  11997.12             False
# 197 -0.041663  NaN  0.675373 -0.020560     NaN  11364.11             False
# 198  1.200918  NaN -1.425309 -0.020560     NaN  28143.21             False
# 199 -0.918779  NaN -1.413087 -0.020560     NaN   9823.54             False
#
#      region_southeast  region_southwest  bmi_category_normal  \
# ...

# %%
final_df['sex'].unique
# Out:
# <bound method Series.unique of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# Name: sex, Length: 200, dtype: float64>

# %%
final_df['sex'] = final_df['sex'].map({
    'male': 0,
    'female': 1
})

# %%
final_df.head()
# Out:
#         age  sex       bmi  children  smoker   charges  bmi_category_normal  \
# 0  1.054732    1  1.508007 -0.020560       1  13728.85                False
# 1  0.323802    0  1.376619  1.350107       0  27106.08                False
# 2 -0.699500    1 -0.455176 -1.391227       0  23420.40                False
# 3  1.347105    0 -1.646836  0.664774       0  25290.53                False
# 4 -1.211152    0  1.420925 -1.391227       0  24459.64                False
#
#    bmi_category_overweignt  bmi_category_obese  region_northwest  \
# 0                    False                True             False
# 1                    False                True             False
# 2                     True               False             False
# 3                    False               False             False
# 4                    False                True             False
#
#    region_southeast  region_southwest  charges_bin
# 0             False             False            2
# ...

# %%
final_df.isnull().sum()
# Out:
# age                          0
# sex                        200
# bmi                          0
# children                     0
# smoker                     200
# charges                      0
# region_northwest             0
# region_southeast             0
# region_southwest             0
# bmi_category_normal          0
# bmi_category_overweignt      0
# bmi_category_obese           0
# charges_bin                  0
# dtype: int64

# %%
final_df.columns.tolist()
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'charges',
#  'region_northwest',
#  'region_southeast',
#  'region_southwest',
#  'bmi_category_normal',
#  'bmi_category_overweignt',
#  'bmi_category_obese',
#  'charges_bin']

# %%
final_df["sex"].value_counts(dropna=False)
final_df["smoker"].value_counts(dropna=False)
# Out:
# smoker
# NaN    200
# Name: count, dtype: int64

# %%
final_df["sex"] = final_df["sex"].fillna(0)
final_df["smoker"] = final_df["smoker"].fillna(0)

# %%
final_df.isnull().sum()
# Out:
# age                        0
# sex                        0
# bmi                        0
# children                   0
# smoker                     0
# charges                    0
# region_northwest           0
# region_southeast           0
# region_southwest           0
# bmi_category_normal        0
# bmi_category_overweignt    0
# bmi_category_obese         0
# charges_bin                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x = final_df.drop("charges", axis=1)
y = final_df['charges']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred#prediction of y
# Out:
# array([ 7200.747978  , 12573.49499048, 15463.4023465 , 21837.70799419,
#        12134.2016058 ,  6490.67456802, 20117.84414901, 15898.44536258,
#        21637.21048022, 11496.90800826, 10595.19286112, 15391.217237  ,
#        15012.87458464,  5951.9088699 , 18222.02804643, 10486.47162206,
#        10963.42675196, 11069.9957922 , 15531.46089287, 21564.96478213,
#        16127.74546027, 11197.0109552 ,  6667.20192003, 22464.8567757 ,
#         7162.12269045, 10199.07801652, 15535.99717535, 12689.26773414,
#        22193.21798397, 11434.14331277,  7235.99006164,  6314.07232853,
#        10959.67895738, 11156.34865991, 15548.27583052,  7146.72007805,
#         7525.82971641,  6474.56237263, 22841.12681586, 22537.07223147])

# %%
y_test #actual value of y means charges
# Out:
# 95      5834.16
# 15     10532.68
# 30     13701.90
# 158    26171.92
# 128    10170.75
# 115     5144.49
# 69     26888.71
# 170    13012.82
# 174    25577.42
# 45     11000.76
# 66     10165.34
# 182    11993.98
# 165    13154.20
# 78      9629.41
# 186    12292.80
# 177    10646.55
# 56     10675.15
# 152    10040.15
# 82     11782.09
# 68     28416.93
# 124    13082.63
# 16     10661.33
# 148     9055.92
# 93     21869.57
# 65      8419.26
# 60     11291.10
# 84     13806.75
# 67     10722.21
# 125    28410.22
# 132    10731.76
# 9       6705.71
# 18      9713.82
# 55     10365.21
# 75     10718.67
# 150    12056.08
# 104     9566.48
# 135     9144.52
# 137     7215.62
# 164    22467.67
# 76     24306.43
# Name: charges, dtype: float64

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.7984879853793376

# %%
n = x_test.shape[0]
p=x_test.shape[1]
adjusted_r2 = 1- ((1-r2)*(n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.7089270899923765

# %%
y_train
# Out:
# 79     12705.23
# 197    11364.11
# 38     24833.18
# 24     26698.58
# 122    28040.58
#          ...
# 106    11167.43
# 14     21717.11
# 92     12334.88
# 179    21396.40
# 102    22503.87
# Name: charges, Length: 160, dtype: float64
